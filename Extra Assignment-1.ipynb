# %%
#PRINT STATEMENT
print("HOPE AI")
# Out:
# HOPE AI

# %%
#BUY INPUT
name=input("Enter your institute name? : ")
# Out:
# Enter your institute name? :  HOPE AI

# %%
#BUY INPUTSname=input("Enter your name? : ")
age=input("Enter your age? : ")
school=input("Enter your school name? : ")
degree=input("Enter your degree? : ")
# Out:
# Enter your name? :  Raj
# Enter your age? :  15
# Enter your school name? :  Guru school
# Enter your degree? :  B.E CSE

# %%
#ADDITION
num1=int(input("a= "))
num2=int(input("b= "))
print("add= ",num1+num2)
# Out:
# a=  43
# b=  34
# add=  77

# %%
#SUBTRACTION
num1=int(input("a="))
num2=int(input("b="))
print("sub=",num1-num2)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
#Multiplication
num1=int(input("a="))
num2=int(input("b="))
print("mul=",num1*num2)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
#Division
num1=int(input("a="))
num2=int(input("b="))
print("Float Div",num1/num2)
# Out:
# a= 76
# b= 31
# Float Div 2.4516129032258065

# %%
#Floor Division
num1=int(input("a="))
num2=int(input("b="))
print("Floor Div",num1//num2)
# Out:
# a= 76
# b= 31
# Floor Div 2

# %%
#Modulo
num1=int(input("a="))
num2=int(input("b="))
print("Modulo=",num1%num2)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
#Modulo
num1=int(input("a="))
num2=int(input("b="))
print("Modulo=",num1%num2)
# Out:
# a= 4
# b= 4
# Modulo= 0
