# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age==18):
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 88

# %%
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %%
lists=[12,84,8,38,28,68,48,58]

# %%
for temp in lists:
    print(temp)
# Out:
# 12
# 84
# 8
# 38
# 28
# 68
# 48
# 58

# %%
for age in lists:
    if(age<18):
        print("Children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Children
# Senior Citizen
# Children
# Citizen
# Adult
# Senior Citizen
# Citizen
# Citizen

# %%
num=int(input("Enter the number"))
if((num%2)==1):
    print("Odd number")
else:
    print("Even number")
# Out:
# Enter the number 8
# Even number
